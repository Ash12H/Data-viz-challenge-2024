# %%
import pandas as pd
import plotly.express as px
from dash import dash_table

pd.options.plotting.backend = "plotly"

# %%
data = pd.read_csv(
    "../../data/1_raw/youth_not_in_education_employment_or_training.csv", sep=";"
)

# %% [markdown]
# ## Remove empty

# %%
data = data.dropna(axis="columns", how="all")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 566 entries, 0 to 565
# Data columns (total 20 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   STRUCTURE                                    566 non-null    object
#  1   STRUCTURE_ID                                 566 non-null    object
#  2   STRUCTURE_NAME                               566 non-null    object
#  3   ACTION                                       566 non-null    object
#  4   FREQ                                         566 non-null    object
#  5   Fréquence                                    566 non-null    object
#  6   GEO_PICT                                     566 non-null    object
#  7   Pays et territoires insulaires du Pacifique  566 non-null    object
#  8   INDICATOR                                    566 non-null    object
#  9   Indicateur                                   566 non-null    object
#  10  SEX                                          566 non-null    object
#  11  Sexe                                         566 non-null    object
#  12  URBANIZATION                                 566 non-null    object
#  13  Urbanisation                                 566 non-null    object
#  14  DISABILITY                                   566 non-null    object
#  15  Invalidité                                   566 non-null    object
#  16  TIME_PERIOD                                  566 non-null    int64
#  17  OBS_VALUE                                    566 non-null    float64
#  18  UNIT_MEASURE                                 566 non-null    object
#  19  Unité de mesure                              566 non-null    object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 88.6+ KB

# %%
columns = [
    "Pays et territoires insulaires du Pacifique",
    "Indicateur",
    "Sexe",
    "Urbanisation",
    "Invalidité",
    "TIME_PERIOD",
    "OBS_VALUE",
]
data = data[columns]

# %%
for i in [
    "Pays et territoires insulaires du Pacifique",
    "Indicateur",
    "Sexe",
    "Urbanisation",
    "Invalidité",
]:
    data[i] = data[i].astype("category")

# %%
data.describe(include="all")
# Out:
#        Pays et territoires insulaires du Pacifique  \
# count                                          566
# unique                                          13
# top                                          Tonga
# freq                                           144
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#                                                Indicateur   Sexe Urbanisation  \
# count                                                 566    566          566
# unique                                                  2      3            3
# top     Nombre de jeunes personnes sans études, emploi...  Total     National
# freq                                                  283    198          216
# mean                                                  NaN    NaN          NaN
# std                                                   NaN    NaN          NaN
# min                                                   NaN    NaN          NaN
# 25%                                                   NaN    NaN          NaN
# 50%                                                   NaN    NaN          NaN
# 75%                                                   NaN    NaN          NaN
# max                                                   NaN    NaN          NaN
#
#                              Invalidité  TIME_PERIOD     OBS_VALUE
# count                               566   566.000000    566.000000
# unique                                3          NaN           NaN
# top     Pas de ventilation par handicap          NaN           NaN
# freq                                308          NaN           NaN
# mean                                NaN  2016.473498   1358.020565
# std                                 NaN     2.669096   3505.552797
# min                                 NaN  2011.000000      6.000000
# 25%                                 NaN  2015.000000     33.000000
# 50%                                 NaN  2016.000000     51.175000
# 75%                                 NaN  2019.000000    916.500000
# max                                 NaN  2021.000000  36037.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 566 entries, 0 to 565
# Data columns (total 7 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Pays et territoires insulaires du Pacifique  566 non-null    category
#  1   Indicateur                                   566 non-null    category
#  2   Sexe                                         566 non-null    category
#  3   Urbanisation                                 566 non-null    category
#  4   Invalidité                                   566 non-null    category
#  5   TIME_PERIOD                                  566 non-null    int64
#  6   OBS_VALUE                                    566 non-null    float64
# dtypes: category(5), float64(1), int64(1)
# memory usage: 12.9 KB

# %%
data = data.pivot_table(
    index=[
        "Pays et territoires insulaires du Pacifique",
        "Sexe",
        "Urbanisation",
        "Invalidité",
        "TIME_PERIOD",
    ],
    columns="Indicateur",
    values="OBS_VALUE",
).reset_index()
data = data[data.columns[data.notna().sum() > 10]]
data.head()
# Out:
# /var/folders/36/grrgsqjd14j4tf6cf5ty4ykh0000gn/T/ipykernel_14037/1078403353.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   data = data.pivot_table(
# Indicateur Pays et territoires insulaires du Pacifique   Sexe Urbanisation  \
# 0                                             Kiribati  Femme     National
# 1                                             Kiribati  Femme     National
# 2                                             Kiribati  Femme     National
# 3                                             Kiribati  Femme     National
# 4                                             Kiribati  Femme     National
#
# Indicateur                       Invalidité  TIME_PERIOD  \
# 0           Pas de ventilation par handicap         2015
# 1           Pas de ventilation par handicap         2019
# 2                     Personnes handicapées         2015
# 3                     Personnes handicapées         2019
# 4                   Personnes sans handicap         2015
#
# Indicateur  Nombre de jeunes personnes sans études, emploi ni formation  \
# 0                                                      5150.0
# 1                                                      5145.0
# 2                                                        42.0
# 3                                                        73.0
# 4                                                      5108.0
#
# Indicateur  Proportion de jeunes personnes sans études, emploi ni formation
# 0                                                       47.06
# 1                                                       48.88
# 2                                                       47.73
# 3                                                       31.20
# 4                                                       47.06

# %%
data.to_parquet(
    "../../data/2_clean/youth_not_in_education_employment_or_training.parquet"
)
